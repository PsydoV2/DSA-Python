# %% [markdown]
# # Lists
#
# - General purpose
# - Most widely used data structure
# - Grow and shrink size as needed
# - Sequence type
# - Sortable

# %% [markdown]
# ### constructors

# %%
x = list()
